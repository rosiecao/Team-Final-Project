# %%
# Imports for machine learning model

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
#Skeleton for our model

# Load the data
file_path = Path('./Resources/Machine Learning Features.csv')
df = pd.read_csv(file_path)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# %%
df.head()
# Out:
#    Unnamed: 0 AnalysisNeighborhood   AvgHomeCost  CS Score  \
# 0           0              Bayview  349602.14105    1.7384
# 1           1              Bayview  349602.14105    1.7384
# 2           2              Bayview  349602.14105    1.7384
# 3           3              Bayview  349602.14105    1.7384
# 4           4              Bayview  349602.14105    1.7384
#
#                                             the_geom  TRACTCE10  PTrans_Sco  \
# 0  MULTIPOLYGON (((-122.38903499954088 37.7329189...      23200      13.758
# 1  MULTIPOLYGON (((-122.38155800020716 37.7381230...      23102      13.758
# 2  MULTIPOLYGON (((-122.39262499954708 37.7292780...      23300      13.758
# 3  MULTIPOLYGON (((-122.38451700015729 37.7228620...      23400      13.758
# 4  MULTIPOLYGON (((-122.39594499999093 37.7377840...      23001      13.758
#
#    Trans_Sco  VCrim_Rate  LivAl_Per  EldLivAl_Per  Viol_Rate   Emp_per  \
# 0        1.0     105.799   0.224654      0.073887       7.78  0.838265
# 1        1.0     105.799   0.224654      0.073887       7.78  0.838265
# 2        1.0     105.799   0.224654      0.073887       7.78  0.838265
# 3        1.0     105.799   0.224654      0.073887       7.78  0.838265
# 4        1.0     105.799   0.224654      0.073887       7.78  0.838265
#
#    Ec_Score   Pov_Per  PopDens  DayPopDens  Res_Score
# 0       1.0  0.413469  6944.77     9850.25        1.0
# 1       1.0  0.413469  6944.77     9850.25        1.0
# 2       1.0  0.413469  6944.77     9850.25        1.0
# 3       1.0  0.413469  6944.77     9850.25        1.0
# 4       1.0  0.413469  6944.77     9850.25        1.0

# %%
#drop columns that wont be used
df = df.drop(columns = ['the_geom', 'TRACTCE10'])

#drop duplicate neighborhoods
df = df.drop_duplicates(subset=['AnalysisNeighborhood'])

# %%
df.head()
# Out:
#     Unnamed: 0 AnalysisNeighborhood    AvgHomeCost  CS Score  PTrans_Sco  \
# 0            0              Bayview  349602.141050  1.738400     13.7580
# 11          11       Bernal Heights  481784.205633  1.788646     28.6832
# 17          17  Castro/Upper Market  803432.976477  1.791669     36.8504
# 23          23            Chinatown  945772.065002  1.565266     89.9066
# 27          27            Excelsior  344472.019289  1.705869     23.0295
#
#     Trans_Sco  VCrim_Rate  LivAl_Per  EldLivAl_Per  Viol_Rate   Emp_per  \
# 0         1.0    105.7990   0.224654      0.073887       7.78  0.838265
# 11        3.0     43.7684   0.243070      0.050114       6.90  0.927948
# 17        4.0     64.1234   0.428756      0.077243       9.34  0.930183
# 23        5.0     50.8277   0.473996      0.247639      10.59  0.842658
# 27        2.0     34.5181   0.177211      0.082659       4.33  0.913833
#
#     Ec_Score   Pov_Per   PopDens  DayPopDens  Res_Score
# 0        1.0  0.413469   6944.77     9850.25        1.0
# 11       3.0  0.242756  22066.80    16503.80        3.0
# 17       4.0  0.161876  23023.00    18531.00        5.0
# 23       1.0  0.657467  70416.60   278476.00        1.0
# 27       2.0  0.294074  23767.50    21733.00        2.0

# %%
df['VCrim_Rate'].mean()
# Out:
# 45.83977666666668

# %%
df['CS Score'].mean()
# Out:
# 1.7583995177741463

# %%
# Create categories for low crime and high crime 

col1= 'CS Score'
col2= 'VCrim_Rate'

conditions = [ (df[col1] >= 1.75) | (df[col2] >= 70), (df[col1] < 1.74) | (df[col2] < 69)]

choices = [ "more crime", 'less crime']

df["CS"] = np.select(conditions, choices, default=np.nan)

# %%
df
# Out:
#      Unnamed: 0       AnalysisNeighborhood   AvgHomeCost  CS Score  \
# 0             0                    Bayview  3.496021e+05  1.738400
# 11           11             Bernal Heights  4.817842e+05  1.788646
# 17           17        Castro/Upper Market  8.034330e+05  1.791669
# 23           23                  Chinatown  9.457721e+05  1.565266
# 27           27                  Excelsior  3.444720e+05  1.705869
# 34           34             Crocker Amazon  3.444720e+05  1.705869
# 38           38  Diamond Heights/Glen Park  5.779448e+05  1.857835
# 41           41             Haight Ashbury  8.288059e+05  1.781447
# 45           45      Downtown/Civic Center  8.016554e+05  1.813581
# 50           50             Inner Richmond  6.943029e+05  1.708699
# 54           54               Inner Sunset  6.031309e+05  1.805232
# 60           60            Pacific Heights  5.065034e+05  1.829474
# 61           61                  Lakeshore  2.803594e+06  1.735369
# 65           65             Outer Richmond  8.715481e+05  1.872705
# 66           66           Western Addition  6.551503e+05  1.723252
# 69           69                     Marina  1.167930e+06  1.844743
# 77           77                    Mission  6.340985e+05  1.689780
# 91           91                   Nob Hill  1.067856e+06  1.741671
# 98           98                 Noe Valley  7.476375e+05  1.926499
# 104         104                North Beach  8.342235e+05  1.761552
# 107         107                 Ocean View  3.457159e+05  1.696323
# 112         112              Outer Mission  3.666917e+05  1.644503
# 136         136               Potrero Hill  6.390039e+05  1.826707
# 143         143               Russian Hill  1.013545e+06  1.825446
# 148         148            South of Market  8.435418e+05  1.679589
# 152         152               Outer Sunset  4.284264e+05  1.678197
# 155         155                   Parkside  4.284264e+05  1.678197
# 174         174                 Twin Peaks  6.522030e+05  1.857459
# 176         176          Visitacion Valley  3.125011e+05  1.676561
# 181         181         West of Twin Peaks  5.782016e+05  1.801446
#
#      PTrans_Sco  Trans_Sco  VCrim_Rate  LivAl_Per  EldLivAl_Per  Viol_Rate  \
# 0      13.75800        1.0    105.7990   0.224654      0.073887       7.78
# 11     28.68320        3.0     43.7684   0.243070      0.050114       6.90
# 17     36.85040        4.0     64.1234   0.428756      0.077243       9.34
# 23     89.90660        5.0     50.8277   0.473996      0.247639      10.59
# 27     23.02950        2.0     34.5181   0.177211      0.082659       4.33
# 34     18.53950        1.0     20.6687   0.174093      0.064249       3.83
# 38     24.68570        2.0     20.3355   0.376537      0.101817       5.47
# 41     34.60760        4.0     29.4977   0.401279      0.062053       8.46
# 45     83.29560        5.0    177.4700   0.676120      0.144177       9.06
# 50     26.20580        3.0     17.3871   0.333675      0.071877       6.08
# 54     23.82810        2.0     13.3170   0.334670      0.073262       5.54
# 60     48.40620        4.0     15.3943   0.549776      0.117156       5.53
# 61      7.97374        1.0     22.6632   0.327530      0.146899       2.18
# 65     19.17430        3.0     15.5209   0.342475      0.104658       4.07
# 66     50.18250        5.0     48.1178   0.520403      0.158978       8.15
# 181  0.931076       4.0  0.140829  10847.90    11760.30        5.0  more crime

# %% [markdown]
# ## Split into Train and Test

# %%
# Create our features
X = df.drop("CS", axis=1)

X = pd.get_dummies(X)

# Create our target
y = df["CS"]

# %%
X.describe()
# Out:
#        Unnamed: 0   AvgHomeCost   CS Score  PTrans_Sco  Trans_Sco  VCrim_Rate  \
# count   30.000000  3.000000e+01  30.000000   30.000000  30.000000   30.000000
# mean    83.833333  7.224058e+05   1.758400   34.452245   2.966667   45.839777
# std     53.763905  4.577831e+05   0.080385   22.422704   1.519604   42.826430
# min      0.000000  3.125011e+05   1.565266    7.973740   1.000000   13.175500
# 25%     42.000000  4.417659e+05   1.698709   18.698200   2.000000   18.124200
# 50%     67.500000  6.456034e+05   1.751611   26.096650   3.000000   29.702150
# 75%    130.000000  8.328691e+05   1.822479   45.684350   4.000000   52.898900
# max    181.000000  2.803594e+06   1.926499   89.906600   5.000000  177.470000
#
#        LivAl_Per  EldLivAl_Per  Viol_Rate    Emp_per  ...  \
# count  30.000000     30.000000  30.000000  30.000000  ...
# mean    0.370484      0.100716   6.259667   0.917259  ...
# std     0.142839      0.040534   2.326066   0.031937  ...
# min     0.174093      0.042092   2.180000   0.838265  ...
# 25%     0.222506      0.074401   4.300000   0.906547  ...
# 50%     0.371407      0.087374   5.655000   0.927877  ...
# 75%     0.508801      0.116617   8.070000   0.933269  ...
# max     0.676120      0.247639  10.590000   0.965727  ...
#
#        AnalysisNeighborhood_Outer Sunset  \
# count                          30.000000
# mean                            0.033333
# std                             0.182574
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             1.000000
#
#        AnalysisNeighborhood_Pacific Heights  AnalysisNeighborhood_Parkside  \
# count                             30.000000                      30.000000
# mean                               0.033333                       0.033333
# std                                0.182574                       0.182574
# min                                0.000000                       0.000000
# 25%                                0.000000                       0.000000
# 50%                                0.000000                       0.000000
# 75%                                0.000000                       0.000000
# max                                1.000000                       1.000000
#
#        AnalysisNeighborhood_Potrero Hill  AnalysisNeighborhood_Russian Hill  \
# count                          30.000000                          30.000000
# mean                            0.033333                           0.033333
# std                             0.182574                           0.182574
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           0.000000
# max                             1.000000                           1.000000
#
#        AnalysisNeighborhood_South of Market  AnalysisNeighborhood_Twin Peaks  \
# count                             30.000000                        30.000000
# mean                               0.033333                         0.033333
# std                                0.182574                         0.182574
# min                                0.000000                         0.000000
# 25%                                0.000000                         0.000000
# 50%                                0.000000                         0.000000
# 75%                                0.000000                         0.000000
# max                                1.000000                         1.000000
#
#        AnalysisNeighborhood_Visitacion Valley  \
# count                               30.000000
# mean                                 0.033333
# std                                  0.182574
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        AnalysisNeighborhood_West of Twin Peaks  \
# count                                30.000000
# mean                                  0.033333
# std                                   0.182574
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        AnalysisNeighborhood_Western Addition
# count                              30.000000
# mean                                0.033333
# std                                 0.182574
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
# [8 rows x 45 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# more crime    18
# less crime    12
# Name: CS, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier

from imblearn.ensemble import BalancedRandomForestClassifier
random_forest = BalancedRandomForestClassifier(n_estimators = 100)
random_forest = random_forest.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score

from sklearn.metrics import balanced_accuracy_score
y_pred = random_forest.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8333333333333333

# %%
# Display the confusion matrix

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[2, 1],
#        [0, 5]], dtype=int64)

# %%
# Print the imbalanced classification report

from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#  less crime       1.00      0.67      1.00      0.80      0.82      0.64         3
#  more crime       0.83      1.00      0.67      0.91      0.82      0.69         5
#
# avg / total       0.90      0.88      0.79      0.87      0.82      0.67         8

# %%
# List the features sorted in descending order by feature importance

feature_names = X.columns
sorted(zip(random_forest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.1504486870395704, 'CS Score'),
#  (0.1124685223211627, 'Pov_Per'),
#  (0.08754124713210847, 'LivAl_Per'),
#  (0.07813791980078745, 'AvgHomeCost'),
#  (0.07364877574348727, 'EldLivAl_Per'),
#  (0.06940872273469677, 'Emp_per'),
#  (0.05728978607177137, 'Res_Score'),
#  (0.05271268283507295, 'PopDens'),
#  (0.04779618329655094, 'VCrim_Rate'),
#  (0.04601457946815089, 'Unnamed: 0'),
#  (0.04570901598401599, 'DayPopDens'),
#  (0.04177635667903525, 'Trans_Sco'),
#  (0.031717419281055655, 'PTrans_Sco'),
#  (0.02682199675324675, 'Ec_Score'),
#  (0.02525007284382284, 'Viol_Rate'),
#  (0.010037516436554896, 'AnalysisNeighborhood_Outer Mission'),
#  (0.006519909502262448, 'AnalysisNeighborhood_Chinatown'),
#  (0.006075892857142857, 'AnalysisNeighborhood_Bayview'),
#  (0.005061824178707296, 'AnalysisNeighborhood_Western Addition'),
#  (0.003348214285714286, 'AnalysisNeighborhood_Outer Richmond'),
#  (0.002777004813368448, 'AnalysisNeighborhood_Haight Ashbury'),
#  (0.0024937908496732012, 'AnalysisNeighborhood_Excelsior'),
#  (0.0024885408708938137, 'AnalysisNeighborhood_Bernal Heights'),
#  (0.002437500000000001, 'AnalysisNeighborhood_Mission'),
#  (0.0020697167755991284, 'AnalysisNeighborhood_Parkside'),
#  (0.001625668449197861, 'AnalysisNeighborhood_Castro/Upper Market'),
#  (0.0016180555555555568, 'AnalysisNeighborhood_West of Twin Peaks'),
#  (0.0015625000000000003, 'AnalysisNeighborhood_Ocean View'),
#  (0.0015584415584415584, 'AnalysisNeighborhood_Outer Sunset'),
#  (0.0012500000000000002, 'AnalysisNeighborhood_Pacific Heights'),
#  (0.0011764705882352934, 'AnalysisNeighborhood_Diamond Heights/Glen Park'),
#  (0.000628413865546218, 'AnalysisNeighborhood_Crocker Amazon'),
#  (0.00042857142857142904, 'AnalysisNeighborhood_Noe Valley'),
#  (9.999999999999965e-05, 'AnalysisNeighborhood_Lakeshore'),
#  (0.0, 'AnalysisNeighborhood_Visitacion Valley'),
#  (0.0, 'AnalysisNeighborhood_Twin Peaks'),
#  (0.0, 'AnalysisNeighborhood_South of Market'),
#  (0.0, 'AnalysisNeighborhood_Russian Hill'),
#  (0.0, 'AnalysisNeighborhood_Potrero Hill'),
#  (0.0, 'AnalysisNeighborhood_North Beach'),
#  (0.0, 'AnalysisNeighborhood_Nob Hill'),
#  (0.0, 'AnalysisNeighborhood_Marina'),
#  (0.0, 'AnalysisNeighborhood_Inner Sunset'),
#  (0.0, 'AnalysisNeighborhood_Inner Richmond'),
#  (0.0, 'AnalysisNeighborhood_Downtown/Civic Center')]
